# %% [markdown]
# # Data Visualization With Matplotlib

# %% [markdown]
# ## Line Chart
#
# Data source: https://data.oecd.org/conversion/exchange-rates.htm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot') # Other sytles to use; fivethirtyeight

# %%
ex_rate_df=pd.read_csv('Exchange_Rates.csv')

# %%
ex_rate_df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0      AUS      EXCH     TOT  NATUSD         A  2000  1.724827         NaN
# 1      AUS      EXCH     TOT  NATUSD         A  2001  1.933443         NaN
# 2      AUS      EXCH     TOT  NATUSD         A  2002  1.840563         NaN
# 3      AUS      EXCH     TOT  NATUSD         A  2003  1.541914         NaN
# 4      AUS      EXCH     TOT  NATUSD         A  2004  1.359752         NaN

# %%
ex_rate_df['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'COL', 'EST', 'IND',
#        'IDN', 'ISR', 'RUS', 'SVN', 'ZAF', 'LVA', 'LTU', 'SAU', 'EA19',
#        'ARG', 'CRI', 'BGR', 'HRV', 'CYP', 'MLT', 'PER', 'ROU', 'MKD',
#        'MDG', 'MAR', 'ZMB', 'SRB', 'HKG', 'EU27_2020'], dtype=object)

# %% [markdown]
# ###### Let's Plot the Exchange Rate for FRA Currency

# %%
fra_x=ex_rate_df[ex_rate_df['LOCATION']=='FRA']['TIME'].astype(str)
fra_y=ex_rate_df[ex_rate_df['LOCATION']=='FRA']['Value']

# %%
plt.figure(figsize=(20,10)) # Set figure size
plt.rcParams.update({'font.size': 22}) # Set axes size
plt.plot(fra_x,fra_y,color='orange',marker='*') # Plot the chart
plt.title('Exchange rates',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Year',fontsize=24)
plt.ylabel('Rate',fontsize=24)
plt.legend(['FRA'], loc='upper right')
plt.show()

# %% [markdown]
# ###### Multiple Lines in a Graph
# Let's Add more Plots For the Exchange Rate for FRA, BGR and USD Baseline Currency

# %%
fra_x=ex_rate_df[ex_rate_df['LOCATION']=='FRA']['TIME'].astype(str)
fra_y=ex_rate_df[ex_rate_df['LOCATION']=='FRA']['Value']
gbr_x=ex_rate_df[ex_rate_df['LOCATION']=='GBR']['TIME'].astype(str)
gbr_y=ex_rate_df[ex_rate_df['LOCATION']=='GBR']['Value']
usd_x=ex_rate_df[ex_rate_df['LOCATION']=='USA']['TIME'].astype(str)
usd_y=ex_rate_df[ex_rate_df['LOCATION']=='USA']['Value']

# %%
plt.figure(figsize=(20,10)) # Set figure size
plt.rcParams.update({'font.size': 22}) # Set axes size
plt.plot(fra_x,fra_y,color='orange',marker='*',label='FRA') # Plot the chart for AUS
plt.plot(gbr_x,gbr_y,color='skyblue',marker='*',label='GBR') # Plot the chart for IDN
plt.plot(usd_x,usd_y,color='red',marker='*',label='USD',linestyle='--') # Plot the chart for HKG
plt.title('Exchange rates',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Year',fontsize=24)
plt.ylabel('Rate',fontsize=24)
plt.legend(['FRA', 'GBR','USD','RUS'], loc='lower right')
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
score_df = pd.DataFrame(
    {
        "Students": ["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"],
        "Math": [79.00, 67.00,80.00, 84.00, 70.00,60.00,90.00,76.00,75],
        "Physics":[63.00, 98, 60.00, 90,84.00, 77.00,55.00,70,66.00],
        "Computer":[84.00,78.00, 57.00, 88.00, 75.00,93.00,92.00,98.00,90.00],
    },
    index=["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"]
)

score_df['Total']=score_df[['Math','Physics','Computer']].apply(np.sum,axis=1)
score_df
# Out:
#         Students  Math  Physics  Computer  Total
# Tom          Tom  79.0     63.0      84.0  226.0
# Peter      Peter  67.0     98.0      78.0  243.0
# Simon      Simon  80.0     60.0      57.0  197.0
# Mary        Mary  84.0     90.0      88.0  262.0
# Jane        Jane  70.0     84.0      75.0  229.0
# King        King  60.0     77.0      93.0  230.0
# Hillary  Hillary  90.0     55.0      92.0  237.0
# Ethan      Ethan  76.0     70.0      98.0  244.0
# Page        Page  75.0     66.0      90.0  231.0

# %% [markdown]
# ###### Simple Bar Graph

# %%
plt.figure(figsize=(20,10)) # Set figure size
plt.bar(score_df['Students'],score_df['Total'],color='skyblue')
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ###### Add Labels

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center') 
    

plt.figure(figsize=(20,10)) # Set figure size
plt.bar(score_df['Students'],score_df['Total'],color='skyblue')
addlabels(score_df['Students'],score_df['Total'])
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ###### Add Labels at the middle

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2, y[i], ha = 'center')
    

plt.figure(figsize=(20,10)) # Set figure size
plt.bar(score_df['Students'],score_df['Total'],color='skyblue')
addlabels(score_df['Students'],score_df['Total'])
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ###### Horizontal Simple Bar Graph

# %%
plt.figure(figsize=(20,15)) # Set figure size
plt.barh(score_df['Students'],score_df['Total'],color='skyblue')
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ###### Grouped Bar Chart

# %%
score_df[['Math','Physics','Computer']].plot(kind="bar",figsize=(20, 10))

plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ###### Stacked Bar Chart

# %%
score_df[['Math','Physics','Computer']].plot(kind="bar",stacked=True,figsize=(20, 10))
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
iris_df=pd.read_csv('iris.csv')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ###### Simple Scatter Plot
# Let's plot sepal length vs sepal width for Iris-setosa species

# %%
setosa_df=iris_df[iris_df['class']=='Iris-setosa']

plt.figure(figsize=(20,15)) # Set figure size
plt.scatter(setosa_df['sepal_length'],setosa_df['sepal_width'],c='orange')

# %% [markdown]
# ###### Add Classes

# %%
iris_df['class_color']=iris_df['class'].map({'Iris-setosa':'orange','Iris-versicolor':'skyblue','Iris-virginica':'green'})
plt.figure(figsize=(20,15)) # Set figure size
plt.scatter(iris_df['sepal_length'],iris_df['sepal_width'],c=iris_df['class_color'])

# %% [markdown]
# ###### Add Legend

# %%
setosa_df=iris_df[iris_df['class']=='Iris-setosa']
veriscolor_df=iris_df[iris_df['class']=='Iris-versicolor']
virginica_df=iris_df[iris_df['class']=='Iris-virginica']

plt.figure(figsize=(20,15)) # Set figure size
plt.scatter(setosa_df['sepal_length'],setosa_df['sepal_width'],c='orange')
plt.scatter(veriscolor_df['sepal_length'],veriscolor_df['sepal_width'],c='skyblue')
plt.scatter(virginica_df['sepal_length'],virginica_df['sepal_width'],c='green')
plt.legend(['setosa','veriscol0r','virginica'])

# %% [markdown]
# ## Pie Chart

# %%
score_df = pd.DataFrame(
    {
        "Students": ["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"],
        "Math": [79.00, 67.00,80.00, 84.00, 70.00,60.00,90.00,76.00,75],
        "Physics":[63.00, 98, 60.00, 90,84.00, 77.00,55.00,70,66.00],
        "Computer":[84.00,78.00, 57.00, 88.00, 75.00,93.00,92.00,98.00,90.00],
    },
    index=["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"]
)

score_df['Total']=score_df[['Math','Physics','Computer']].apply(np.sum,axis=1)
score_df
# Out:
#         Students  Math  Physics  Computer  Total
# Tom          Tom  79.0     63.0      84.0  226.0
# Peter      Peter  67.0     98.0      78.0  243.0
# Simon      Simon  80.0     60.0      57.0  197.0
# Mary        Mary  84.0     90.0      88.0  262.0
# Jane        Jane  70.0     84.0      75.0  229.0
# King        King  60.0     77.0      93.0  230.0
# Hillary  Hillary  90.0     55.0      92.0  237.0
# Ethan      Ethan  76.0     70.0      98.0  244.0
# Page        Page  75.0     66.0      90.0  231.0

# %% [markdown]
# ###### Simple Pie Chart

# %%
plt.figure(figsize=(20,15)) # Set figure size
plt.pie(score_df['Total'],labels=score_df['Students'])
plt.show()

# %% [markdown]
# ###### Format Pie Chart
# First we add percentages with autopct to show the contribution of each students to the overal score. shadow=True adds shadow to the pie. Explode 1st and 4th pies.

# %%
plt.figure(figsize=(20,15)) # Set figure size
explode_student=[0.1,0,0,0.3,0,0,0,0,0]
plt.pie(score_df['Total'],labels=score_df['Students'],autopct='%1.1f%%',shadow=True,explode=explode_student)
plt.legend(loc='lower right',title='Students',bbox_to_anchor =(1, 0, 0.2, 1))
plt.show()

# %% [markdown]
# ###### Show percentage and Actual data
# First we haev to create a custom function with percentanges and absolute values. Then apply the function to autopct with a lambda function

# %%
def percentage_and_actual_value(percentage, actual_value):
    actual = int(percentage / 100.*np.sum(actual_value))
    return "{:.2f}%\n{:d}".format(percentage, actual)

# %%
plt.figure(figsize=(20,15)) # Set figure size
explode_student=[0.1,0,0,0.3,0,0,0,0,0]
plt.pie(score_df['Total'],labels=score_df['Students'],autopct=lambda x: percentage_and_actual_value(x, score_df['Total']),
        shadow=True,explode=explode_student)
plt.legend(loc='lower right',title='Students',bbox_to_anchor =(1, 0, 0.2, 1))
plt.show()

# %% [markdown]
# ## Histogram
# Histogram shows the distribution of a random variable

# %% [markdown]
# ###### Normal/Gaussian data distribution

# %%
normal_distributed_variable=np.random.normal(10,1,10000) 
plt.figure(figsize=(20,15)) # Set figure size
plt.hist(normal_distributed_variable,100,color = "skyblue")
plt.show()

# %% [markdown]
# ###### Exponential Distribution

# %%
exponential_distributed_variable = np.random.exponential(scale=0.5, size=(1000, 1))
plt.figure(figsize=(20,15)) # Set figure size
plt.hist(exponential_distributed_variable,color = "skyblue")
plt.show()

# %% [markdown]
# ## Area Chart

# %%
ex_rate_df=pd.read_csv('Exchange_Rates.csv')
ex_rate_df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0      AUS      EXCH     TOT  NATUSD         A  2000  1.724827         NaN
# 1      AUS      EXCH     TOT  NATUSD         A  2001  1.933443         NaN
# 2      AUS      EXCH     TOT  NATUSD         A  2002  1.840563         NaN
# 3      AUS      EXCH     TOT  NATUSD         A  2003  1.541914         NaN
# 4      AUS      EXCH     TOT  NATUSD         A  2004  1.359752         NaN

# %%
area_chart_ex_rate_df= pd.crosstab(ex_rate_df['TIME'],ex_rate_df['LOCATION'],values=ex_rate_df['Value'],aggfunc='mean')


area_chart_ex_rate_df.index=area_chart_ex_rate_df.index.astype(str)

area_chart_ex_rate_df.head()
# Out:
# LOCATION       ARG       AUS       AUT       BEL       BGR       BRA  \
# TIME
# 2000      0.999500  1.724827  1.082705  1.082705  2.123275  1.829423
# 2001      0.999500  1.933443  1.116533  1.116533  2.184708  2.349632
# 2002      3.063257  1.840563  1.057559  1.057559  2.076975  2.920363
# 2003      2.900629  1.541914  0.884048  0.884048  1.732702  3.077475
# 2004      2.923301  1.359752  0.803922  0.803922  1.575109  2.925119
#
# LOCATION       CAN       CHE         CHL       CHN  ...        RUS   SAU  \
# TIME                                                ...
# 2000      1.485394  1.688843  539.587500  8.278504  ...  28.129167  3.75
# 2001      1.548840  1.687615  634.938333  8.277068  ...  29.168525  3.75
# 2002      1.570343  1.558607  688.936667  8.276958  ...  31.348483  3.75
# 2003      1.401015  1.346651  691.397500  8.277037  ...  30.692025  3.75
# 2004      1.301282  1.243496  609.529167  8.276801  ...  28.813742  3.75
#
# LOCATION        SRB       SVK       SVN        SWE       TUR  USA        ZAF  \
# TIME
# 2000      63.165900  1.528088  0.929127   9.162244  0.625219  1.0   6.939828
# 2001      66.913660  1.605086  1.012973  10.329136  1.225588  1.0   8.609181
# 2002      64.398251  1.504572  1.002538   9.737123  1.507226  1.0  10.540747
# 2003      57.585425  1.220637  0.864270   8.086304  1.500885  1.0   7.564749
# 2004      58.381400  1.070733  0.802792   7.348887  1.425537  1.0   6.459693
#
# LOCATION       ZMB
# TIME
# 2000      3.110844
# 2001      3.610935
# 2002      4.398595
# 2003      4.733271
# 2004      4.778875
#
# [5 rows x 60 columns]

# %% [markdown]
# ###### Basic Area Chart
# Shows the change over time

# %%
plt.figure(figsize=(20,15)) # Set figure size
plt.stackplot(area_chart_ex_rate_df.index, area_chart_ex_rate_df['ZMB'],
              labels=['ZMB'],
              alpha=0.8)

plt.legend(loc=2, fontsize='large',title='Country')
plt.xticks(rotation=45)
plt.show()
plt.show()

# %% [markdown]
# ###### Stacked Area Chart
#
# Shows part-to-whole relationships, helping show how each category contributes to the cumulative total.

# %%
plt.figure(figsize=(20,15)) # Set figure size
plt.stackplot(area_chart_ex_rate_df.index, area_chart_ex_rate_df['ZMB'], area_chart_ex_rate_df['SWE'],
              area_chart_ex_rate_df['SVK'],
              labels=['ZMB', 'SWE', 'SVK'],
              alpha=0.8)

plt.legend(loc=2, fontsize='large',title='Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Treemap in Matplotlib
# To plot Treemap we need to install squarify. pip install squarify.
#
# Use Treemap when;
# You have fewer categories
# You have Positive values
# You don't have enough space for multiple visualizations

# %%
# !pip install squarify # install squarify. Uncomment to install if using jupyter notebook

# %%
salary_df = pd.DataFrame(
    {
        "Staff": ["Tom", "Peter","Simon", "Mary", "Jane"],
        "Salary": [90000.00, 57000.00,40000.00, 34000.00, 12000.00]
    },
)

salary_df
# Out:
#    Staff   Salary
# 0    Tom  90000.0
# 1  Peter  57000.0
# 2  Simon  40000.0
# 3   Mary  34000.0
# 4   Jane  12000.0

# %%
import squarify 

plt.figure(figsize=(20,15)) # Set figure size
color = ['red', 'green', 'skyblue', 'orange','magenta']
squarify.plot(salary_df['Salary'], label = salary_df['Staff'], color=color, pad = True, alpha=.8)
plt.axis('off')
plt.show()

# %% [markdown]
# ## HeatMap in Matplotlib

# %% [markdown]
# ###### 1. Creating Heatmap with imshow

# %%
heatmap_data = np.random.random(( 10 , 10 ))

plt.figure(figsize=(15,15)) # Set figure size
plt.imshow(heatmap_data,cmap='autumn')
plt.colorbar()
plt.title('2-D Heatmap with imshow')
plt.show()

# %% [markdown]
# ###### Creating Heatmap with pcolormesh

# %%
heatmap_data = np.random.random(( 10 , 10 ))

plt.figure(figsize=(15,15)) # Set figure size
plt.pcolormesh(heatmap_data, cmap = 'summer')
plt.colorbar()
plt.title('2-D Heatmap with pcolormesh')
plt.show()

# %% [markdown]
# ###### Creating Heatmap from DataFrame

# %%
ex_rate_df=pd.read_csv('Exchange_Rates.csv')
ex_rate_df.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 0      AUS      EXCH     TOT  NATUSD         A  2000  1.724827         NaN
# 1      AUS      EXCH     TOT  NATUSD         A  2001  1.933443         NaN
# 2      AUS      EXCH     TOT  NATUSD         A  2002  1.840563         NaN
# 3      AUS      EXCH     TOT  NATUSD         A  2003  1.541914         NaN
# 4      AUS      EXCH     TOT  NATUSD         A  2004  1.359752         NaN

# %%
heatmap_ex_rate_df= pd.crosstab(ex_rate_df['TIME'],ex_rate_df['LOCATION'],values=ex_rate_df['Value'],aggfunc='mean')

heatmap_ex_rate_df.iloc[0:,0:13]
# Out:
# LOCATION        ARG       AUS       AUT       BEL       BGR       BRA  \
# TIME
# 2000       0.999500  1.724827  1.082705  1.082705  2.123275  1.829423
# 2001       0.999500  1.933443  1.116533  1.116533  2.184708  2.349632
# 2002       3.063257  1.840563  1.057559  1.057559  2.076975  2.920363
# 2003       2.900629  1.541914  0.884048  0.884048  1.732702  3.077475
# 2004       2.923301  1.359752  0.803922  0.803922  1.575109  2.925119
# 2005       2.903658  1.309473  0.803800  0.803800  1.574133  2.434390
# 2006       3.054313  1.327973  0.796433  0.796433  1.559267  2.175327
# 2007       3.095649  1.195073  0.729672  0.729672  1.429050  1.947058
# 2008       3.144165  1.192178  0.679923  0.679923  1.337117  1.833767
# 2009       3.710107  1.282189  0.716958  0.716958  1.406692  1.999428
# 2010       3.896295  1.090159  0.754309  0.754309  1.477392  1.759227
# 2011       4.110140  0.969463  0.718414  0.718414  1.406458  1.672829
# 2012       4.536934  0.965801  0.778338  0.778338  1.522050  1.953069
# 2013       5.459353  1.035843  0.752945  0.752945  1.473567  2.156089
# 2014       8.075276  1.109363  0.752728  0.752728  1.474183  2.352952
# 2015       9.233186  1.331090  0.901296  0.901296  1.764400  3.326904
# 2016      14.758175  1.345214  0.903421  0.903421  1.768042  3.491313
# 2017      16.562707  1.304758  0.885206  0.885206  1.735458  3.191389
# 2018      28.094992  1.338412  0.846773  0.846773  1.657042  3.653825
# 2019      48.147892  1.438507  0.893276  0.893276  1.747042  3.944471
# 2020      70.539167  1.453085  0.875506  0.875506  1.716333  5.155179
#
# LOCATION       CAN       CHE         CHL       CHN          COL         CRI  \
# TIME
# 2000      1.485394  1.688843  539.587500  8.278504  2087.903842  308.186667
# 2001      1.548840  1.687615  634.938333  8.277068  2299.633156  328.870833
# 2002      1.570343  1.558607  688.936667  8.276958  2504.241331  359.817527
# 2003      1.401015  1.346651  691.397500  8.277037  2877.652458  398.662222
# 2004      1.301282  1.243496  609.529167  8.276801  2628.612903  437.935000
# 2005      1.211405  1.245177  559.767500  8.194317  2320.834177  477.786741
# 2006      1.134345  1.253843  530.275000  7.973438  2361.139407  511.301818
# 2007      1.074046  1.200366  522.464167  7.607532  2078.291837  516.617390
# 2008      1.067087  1.083090  522.461036  6.948655  1967.711309  526.235513
# 2009      1.141535  1.088142  560.859895  6.831416  2158.255903  573.287957
# 2010      1.030113  1.042906  510.249167  6.770269  1898.569636  525.829201
# 2011      0.989258  0.888042  483.667500  6.461461  1848.139470  505.664240
# 2012      0.999365  0.937684  486.471303  6.312333  1796.895912  502.901462
# 2013      1.030137  0.926904  495.272878  6.195758  1868.785327  499.766833
# 2014      1.104747  0.916151  570.348216  6.143434  2001.781048  538.317200
# 2015      1.278786  0.962381  654.124084  6.227489  2741.880855  534.565770
# 2016      1.325615  0.985394  676.957736  6.644478  3054.121673  544.739367
# 2017      1.297936  0.984692  648.833793  6.758755  2951.327402  567.513090
# 2018      1.295818  0.977883  641.276813  6.615957  2955.703970  576.972501
# 2019      1.326793  0.993775  702.897423  6.908385  3280.831631  587.294596
# 2020      1.341153  0.938895  792.727206  6.900767  3694.854072  584.900855
#
# LOCATION       CYP
# TIME
# 2000      1.063449
# 2001      1.098814
# 2002      1.043375
# 2003      0.884104
# 2004      0.800652
# 2005      0.792912
# 2006      0.784104
# 2007      0.728078
# 2008      0.679923
# 2009      0.716958
# 2010      0.754309
# 2011      0.718414
# 2012      0.778338
# 2013      0.752945
# 2014      0.752728
# 2015      0.901296
# 2016      0.903421
# 2017      0.885206
# 2018      0.846773
# 2019      0.893276
# 2020      0.875506

# %%
heatmap_ex_rate_df.iloc[0:,0:13].style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col3,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col4,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col12,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col6,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col7,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col8,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow12_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow12_col10,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow14_col9{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col10{
#             background-color:  #c8e366;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col3{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col4,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow17_col11{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col0{
#             background-color:  #0b8566;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col6{
#             background-color:  #daec66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col7,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col9,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col3,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col4,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col7,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col9,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col12,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col6,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col9,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col9,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow4_col9,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow20_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow20_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow20_col8,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow20_col10{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col8{
#             background-color:  #2e9666;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col10{
#             background-color:  #279366;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow0_col12{
#             background-color:  #eaf466;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow10_col7,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow14_col5{
#             background-color:  #319866;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col6,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow18_col11{
#             background-color:  #f6fb66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col8,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow17_col12,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col3{
#             background-color:  #7dbe66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col10,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow6_col4,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow9_col6{
#             background-color:  #43a166;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow1_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow13_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow13_col6{
#             background-color:  #128866;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow4_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow5_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow6_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow7_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow8_col0{
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col1{
#             background-color:  #e7f366;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col3{
#             background-color:  #ddee66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col4{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col9{
#             background-color:  #5bad66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col7{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col8{
#             background-color:  #aad466;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col10,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow6_col1{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col11{
#             background-color:  #2f9766;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow2_col12{
#             background-color:  #deee66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col0,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow10_col5,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col10,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow13_col9{
#             background-color:  #068266;
#             color:  #f1f1f1;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col1{
#             background-color:  #98cc66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col2,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col3,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col4,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow4_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow20_col12{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col5{
#             background-color:  #67b366;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col6,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow11_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow19_col8{
#             background-color:  #b5da66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col7{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col8{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col10,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow18_col5{
#             background-color:  #91c866;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col11,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow9_col9{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow3_col12{
#             background-color:  #7cbe66;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow4_col1,#T_95d7eb18_5cbb_11ec_ae38_94e6f768065erow4_col8{
#             background-color:  #68b366;
#             color:  #000000;
#         }#T_95d7eb18_5cbb_11ec_ae38

# %% [markdown]
# ## Boxplot in Matplotlib
# Boxplot is atype of visualization used for summarizing the characteristics of groups of data. It shows important staistics such as Minimum values, Maximum, First Qquartile (25%), Median (Second Qquartile/50%) and Third Quartile (75%). It's also used for detecting outliers in data.

# %% [markdown]
# ###### Simple Boxplot

# %%
boxplot_df1=np.random.normal(35, 20, 100)

plt.figure(figsize=(15,12)) # Set figure size
plt.boxplot(boxplot_df1)
plt.show()

# %% [markdown]
# ###### Boxplot with DataFrame data

# %%
ex_rate_df=pd.read_csv('Exchange_Rates.csv')
ex_rate_df=ex_rate_df[ex_rate_df['LOCATION'].isin(['AUT','BEL','FRA','GBR'])]
boxplot_ex_rate_df= pd.crosstab(ex_rate_df['TIME'],ex_rate_df['LOCATION'],values=ex_rate_df['Value'],aggfunc='mean')

boxplot_ex_rate_df.head()
# Out:
# LOCATION       AUT       BEL       FRA       GBR
# TIME
# 2000      1.082705  1.082705  1.082705  0.660931
# 2001      1.116533  1.116533  1.116533  0.694655
# 2002      1.057559  1.057559  1.057559  0.667223
# 2003      0.884048  0.884048  0.884048  0.612472
# 2004      0.803922  0.803922  0.803922  0.546180

# %%
GBR=boxplot_ex_rate_df['GBR']
AUT=boxplot_ex_rate_df['AUT']
BEL=boxplot_ex_rate_df['BEL']
FRA=boxplot_ex_rate_df['FRA']

columns=[GBR,AUT,BEL,FRA]

plt.figure(figsize=(15,12)) # Set figure size
plt.boxplot(columns)
plt.xticks([1, 2, 3, 4], ["GBR", "AUT", "BEL", "FRA"], rotation=10)
plt.show()

# %% [markdown]
# ###### Boxplot from Pandas DataFrame

# %%
ex_rate_df.head()
# Out:
#    LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value  Flag Codes
# 21      AUT      EXCH     TOT  NATUSD         A  2000  1.082705         NaN
# 22      AUT      EXCH     TOT  NATUSD         A  2001  1.116533         NaN
# 23      AUT      EXCH     TOT  NATUSD         A  2002  1.057559         NaN
# 24      AUT      EXCH     TOT  NATUSD         A  2003  0.884048         NaN
# 25      AUT      EXCH     TOT  NATUSD         A  2004  0.803922         NaN

# %%
ex_rate_df.boxplot(column=['Value'],by="LOCATION",grid=True, rot=45)
# Out:
# <AxesSubplot:title={'center':'Value'}, xlabel='LOCATION'>

# %% [markdown]
# ## Export Visualizations in Matplotlib

# %%
score_df = pd.DataFrame(
    {
        "Students": ["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"],
        "Math": [79.00, 67.00,80.00, 84.00, 70.00,60.00,90.00,76.00,75],
        "Physics":[63.00, 98, 60.00, 90,84.00, 77.00,55.00,70,66.00],
        "Computer":[84.00,78.00, 57.00, 88.00, 75.00,93.00,92.00,98.00,90.00],
    },
    index=["Tom", "Peter","Simon", "Mary", "Jane","King","Hillary","Ethan","Page"]
)

score_df['Total']=score_df[['Math','Physics','Computer']].apply(np.sum,axis=1)
score_df
# Out:
#         Students  Math  Physics  Computer  Total
# Tom          Tom  79.0     63.0      84.0  226.0
# Peter      Peter  67.0     98.0      78.0  243.0
# Simon      Simon  80.0     60.0      57.0  197.0
# Mary        Mary  84.0     90.0      88.0  262.0
# Jane        Jane  70.0     84.0      75.0  229.0
# King        King  60.0     77.0      93.0  230.0
# Hillary  Hillary  90.0     55.0      92.0  237.0
# Ethan      Ethan  76.0     70.0      98.0  244.0
# Page        Page  75.0     66.0      90.0  231.0

# %% [markdown]
# ###### Save graphs as images

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center') 
    

plt.figure(figsize=(20,10)) # Set figure size
plt.bar(score_df['Students'],score_df['Total'],color='skyblue')
addlabels(score_df['Students'],score_df['Total'])
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.savefig('Students_Score_Bar_Chart.png',bbox_inches='tight') # Save visualization as image
plt.show()

# %%
from IPython.display import Image
Image('Students_Score_Bar_Chart.png')

# %% [markdown]
# ###### Save graphs as PDF

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center') 
    

plt.figure(figsize=(20,10)) # Set figure size
plt.bar(score_df['Students'],score_df['Total'],color='skyblue')
addlabels(score_df['Students'],score_df['Total'])
plt.title('Students Score',fontsize=24)
plt.xticks(rotation=45)
plt.xlabel('Students',fontsize=24)
plt.ylabel('Score',fontsize=24)
plt.savefig('Students_Score_Bar_Chart.pdf',bbox_inches='tight') # Save visualization as image
plt.show()

# %% [markdown]
# ###### Save graphs to Powerpoint
# First we have to install python-pptx. If you're using anaconda open Anaconda Prompt terminal and run the command below: pip install python-pptx.

# %%
from pptx import Presentation
from pptx.util import Inches

ppt = Presentation() # ppt object
slide = ppt.slides.add_slide(ppt.slide_layouts[0]) # Add title slide
slide.shapes.title.text = "Students Score" # Add title
slide2 = ppt.slides.add_slide(ppt.slide_layouts[1]) # Add Bar chart slide
slide2.shapes.title.text = "Students Score Bar Graph" # Add title
slide2.shapes.add_picture('Students_Score_Bar_Chart.png', left= Inches(0.5), top = Inches(1.5),height = Inches(5))
ppt.save('Students_Score.pptx')
